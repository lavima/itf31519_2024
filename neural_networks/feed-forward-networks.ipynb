# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# Load our dataset
dataset = pd.read_csv('../data/heart_failure/heart.csv')
dataset.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# Separate features from targets
features = dataset.drop('HeartDisease',axis=1)
targets = dataset['HeartDisease']

# Encode our targets using one-hot encoding
targets_onehot = pd.get_dummies(targets)
targets_onehot.head()
# Out:
#        0      1
# 0   True  False
# 1  False   True
# 2   True  False
# 3  False   True
# 4   True  False

# %%
# Check distribution of target values
targets.value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
# One-hot encode categorical features
features_onehot = pd.get_dummies(features)
features_onehot.shape
# Out:
# (918, 20)

# %%
# Convert to float (probably not needed, but neural networks use floats 
# internally, so this lets us specify the type explicitly)
features_onehot = features_onehot.astype('float32')
targets_onehot = targets_onehot.astype('float32')
features_onehot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                918 non-null    float32
#  1   RestingBP          918 non-null    float32
#  2   Cholesterol        918 non-null    float32
#  3   FastingBS          918 non-null    float32
#  4   MaxHR              918 non-null    float32
#  5   Oldpeak            918 non-null    float32
#  6   Sex_F              918 non-null    float32
#  7   Sex_M              918 non-null    float32
#  8   ChestPainType_ASY  918 non-null    float32
#  9   ChestPainType_ATA  918 non-null    float32
#  10  ChestPainType_NAP  918 non-null    float32
#  11  ChestPainType_TA   918 non-null    float32
#  12  RestingECG_LVH     918 non-null    float32
#  13  RestingECG_Normal  918 non-null    float32
#  14  RestingECG_ST      918 non-null    float32
#  15  ExerciseAngina_N   918 non-null    float32
#  16  ExerciseAngina_Y   918 non-null    float32
#  17  ST_Slope_Down      918 non-null    float32
#  18  ST_Slope_Flat      918 non-null    float32
#  19  ST_Slope_Up        918 non-null    float32
# dtypes: float32(20)
# memory usage: 71.8 KB

# %%
# Split our data into 90/10
from sklearn.model_selection import train_test_split
train_features, test_features, train_targets, test_targets = train_test_split(features_onehot, targets_onehot, test_size=0.1, stratify=targets)

# %%
import tensorflow as tf

# Convert the dataframes into tensors
train_features_tensor = tf.convert_to_tensor(train_features)
train_targets_tensor = tf.convert_to_tensor(train_targets)
test_features_tensor = tf.convert_to_tensor(test_features)
test_targets_tensor = tf.convert_to_tensor(test_targets)

test_targets.shape
# Out:
# 2024-10-30 11:28:39.162332: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-30 11:28:39.164821: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-30 11:28:39.172711: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730284119.186590   54528 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730284119.190569   54528 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-30 11:28:39.205255: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0000 00:00:1730284120.582451   54528 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# (92, 2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create our neural network. 
model = Sequential([Dense(20,activation='sigmoid'), Dense(2,activation="sigmoid")])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_features, train_targets, epochs=20, batch_size=2)
# Out:
# Epoch 1/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 558us/step - accuracy: 0.5667 - loss: 0.6735
# Epoch 2/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.7330 - loss: 0.5589
# Epoch 3/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.7368 - loss: 0.5469
# Epoch 4/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.7990 - loss: 0.5057
# Epoch 5/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.8036 - loss: 0.4640
# Epoch 6/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8270 - loss: 0.4410
# Epoch 7/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.8492 - loss: 0.3980
# Epoch 8/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.8367 - loss: 0.4083
# Epoch 9/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.8557 - loss: 0.3933
# Epoch 10/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.8536 - loss: 0.3686
# Epoch 11/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.8470 - loss: 0.3732
# Epoch 12/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8765 - loss: 0.3456
# Epoch 13/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.8586 - loss: 0.3493
# Epoch 14/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8753 - loss: 0.3233
# Epoch 15/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.8584 - loss: 0.3481
# Epoch 16/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.8697 - loss: 0.3666
# Epoch 17/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.8806 - loss: 0.3170
# Epoch 18/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.8518 - loss: 0.3538
# Epoch 19/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.8534 - loss: 0.3275
# Epoch 20/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8714 - loss: 0.3382

# %%
model.evaluate(test_features, test_targets)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8825 - loss: 0.3568
# [0.40352463722229004, 0.8586956262588501]

# %%
model_simple = Sequential([Dense(10,activation='sigmoid'), Dense(2,activation="sigmoid")])
model_simple.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_simple.fit(train_features, train_targets, epochs=20, batch_size=2)
# Out:
# Epoch 1/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 557us/step - accuracy: 0.4632 - loss: 0.7226
# Epoch 2/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.6863 - loss: 0.6245
# Epoch 3/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.7229 - loss: 0.5891
# Epoch 4/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.7344 - loss: 0.5617
# Epoch 5/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - accuracy: 0.7183 - loss: 0.5659
# Epoch 6/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.7510 - loss: 0.5479
# Epoch 7/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.7036 - loss: 0.5414
# Epoch 8/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.7290 - loss: 0.5308
# Epoch 9/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.7461 - loss: 0.5266
# Epoch 10/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 0.7368 - loss: 0.5507
# Epoch 11/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.7485 - loss: 0.4972
# Epoch 12/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.7564 - loss: 0.5017
# Epoch 13/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.7613 - loss: 0.5090
# Epoch 14/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.7436 - loss: 0.5092
# Epoch 15/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.7736 - loss: 0.4872
# Epoch 16/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.8018 - loss: 0.4679
# Epoch 17/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.7757 - loss: 0.4940
# Epoch 18/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.7653 - loss: 0.5009
# Epoch 19/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.7980 - loss: 0.4560
# Epoch 20/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.7895 - loss: 0.4773

# %%
model_simple.evaluate(test_features, test_targets)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7485 - loss: 0.5232
# [0.554521918296814, 0.739130437374115]

# %%
# Load and Pre-process the dataset. This code has been copied from the workshop on Regression for Life expectancy

# Load the dataset
dataset2 = pd.read_csv('../data/life_expectancy/Life Expectancy Data.csv')
dataset2.head()

# Drop all rows where we are missing the life expectancy. Had to put the key in a list 
# for this to work in this notebook!?
dataset2 = dataset2.dropna(subset=['Life expectancy '])

# Fill the remaining missing values with the means for each column
float_cols_with_nas = ['Alcohol','Hepatitis B',' BMI ','Polio','Total expenditure','Diphtheria ','GDP','Population',' thinness  1-19 years',' thinness 5-9 years','Income composition of resources','Schooling']
dataset2[float_cols_with_nas] = dataset2[float_cols_with_nas].fillna(dataset2[float_cols_with_nas].mean())

# Convert the categorical columns to appropriate types
dataset2[['Country', 'Status']] = dataset2[['Country', 'Status']].astype('category')

# Encode the categorical columns using one-hot encoding
dataset2 = pd.get_dummies(dataset2)

# Separate into features/targets
targets2 = dataset2['Life expectancy ']
features2 = dataset2.drop('Life expectancy ', axis=1)

from sklearn.model_selection import train_test_split
# Split the data into 75/25 (as specified in the assignment)
train_targets2, test_targets2, train_features2, test_features2 = train_test_split(targets2,features2)

features2.head()
# Out:
#    Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0  2015            263.0             62     0.01               71.279624
# 1  2014            271.0             64     0.01               73.523582
# 2  2013            268.0             66     0.01               73.219243
# 3  2012            272.0             69     0.01               78.184215
# 4  2011            275.0             71     0.01                7.097109
#
#    Hepatitis B  Measles    BMI   under-five deaths   Polio  ...  \
# 0         65.0      1154   19.1                  83    6.0  ...
# 1         62.0       492   18.6                  86   58.0  ...
# 2         64.0       430   18.1                  89   62.0  ...
# 3         67.0      2787   17.6                  93   67.0  ...
# 4         68.0      3013   17.2                  97   68.0  ...
#
#    Country_Uruguay  Country_Uzbekistan  Country_Vanuatu  \
# 0            False               False            False
# 1            False               False            False
# 2            False               False            False
# 3            False               False            False
# 4            False               False            False
#
#    Country_Venezuela (Bolivarian Republic of)  Country_Viet Nam  \
# 0                                       False             False
# 1                                       False             False
# 2                                       False             False
# 3                                       False             False
# 4                                       False             False
#
#    Country_Yemen  Country_Zambia  Country_Zimbabwe  Status_Developed  \
# 0          False           False             False             False
# 1          False           False             False             False
# 2          False           False             False             False
# 3          False           False             False             False
# 4          False           False             False             False
#
#    Status_Developing
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
#
# [5 rows x 204 columns]

# %%
model2 = Sequential([Dense(units=204,activation='sigmoid'), Dense(units=1,activation="linear")])
model2.compile(optimizer='adam',loss='mean_squared_error',metrics=['mean_absolute_error'])
model2.fit(train_features2, train_targets2, epochs=20, batch_size=1)
# Out:
# Epoch 1/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 734us/step - loss: 1758.6888 - mean_absolute_error: 34.7015
# Epoch 2/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 684us/step - loss: 91.6458 - mean_absolute_error: 7.7981
# Epoch 3/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 722us/step - loss: 89.3239 - mean_absolute_error: 7.7755
# Epoch 4/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 844us/step - loss: 86.5736 - mean_absolute_error: 7.5719
# Epoch 5/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 916us/step - loss: 87.7805 - mean_absolute_error: 7.7112
# Epoch 6/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 88.3293 - mean_absolute_error: 7.7153
# Epoch 7/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 3s 929us/step - loss: 87.1603 - mean_absolute_error: 7.6399
# Epoch 8/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 704us/step - loss: 87.1677 - mean_absolute_error: 7.5896
# Epoch 9/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step - loss: 92.0795 - mean_absolute_error: 7.8528
# Epoch 10/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 802us/step - loss: 91.6379 - mean_absolute_error: 7.8207
# Epoch 11/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 700us/step - loss: 83.3573 - mean_absolute_error: 7.4286
# Epoch 12/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 702us/step - loss: 87.3393 - mean_absolute_error: 7.6591
# Epoch 13/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 707us/step - loss: 87.7775 - mean_absolute_error: 7.6627
# Epoch 14/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 707us/step - loss: 91.9827 - mean_absolute_error: 7.9085
# Epoch 15/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 691us/step - loss: 89.5500 - mean_absolute_error: 7.7707
# Epoch 16/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 715us/step - loss: 91.5644 - mean_absolute_error: 7.8065
# Epoch 17/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 687us/step - loss: 85.5742 - mean_absolute_error: 7.5424
# Epoch 18/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 704us/step - loss: 87.9027 - mean_absolute_error: 7.6709
# Epoch 19/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 705us/step - loss: 87.2317 - mean_absolute_error: 7.6065
# Epoch 20/20
# 2196/2196 ━━━━━━━━━━━━━━━━━━━━ 2s 707us/step - loss: 88.0507 - mean_absolute_error: 7.7088

# %%
model2.evaluate(test_features2, test_targets2)
# model2(test_features2[:20].to_numpy())
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 89.1320 - mean_absolute_error: 7.6359
# [86.3584213256836, 7.547824382781982]

# %%
from tensorflow.keras.layers import Normalization

normalization = Normalization(axis=None)
normalization.adapt(train_features2)
model3 = Sequential([normalization,Dense(units=40,activation='sigmoid'),Dense(units=1)])
model3.compile(optimizer='sgd',loss='mean_squared_error',metrics=['mean_absolute_error'])
model3.fit(train_features2, train_targets2, epochs=20, batch_size=24)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 4
#       1 from tensorflow.keras.layers import Normalization
#       3 normalization = Normalization(axis=None)
# ----> 4 normalization.adapt(train_features2)
#       5 model3 = Sequential([normalization,Dense(units=40,activation='sigmoid'),Dense(units=1)])
#       6 model3.compile(optimizer='sgd',loss='mean_squared_error',metrics=['mean_absolute_error'])
#
# File ~/.venv/tensorflow/lib/python3.11/site-packages/keras/src/layers/preprocessing/normalization.py:230, in Normalization.adapt(self, data)
#     227     input_shape = tuple(data.element_spec.shape)
#     229 if not self.built:
# --> 230     self.build(input_shape)
#     231 else:
#     232     for d in self._keep_axis:
#
# UnboundLocalError: cannot access local variable 'input_shape' where it is not associated with a value

# %%
model3.evaluate(test_features2, test_targets2)
model3(test_features2[:40])

# %%
model4 = Sequential()
model4.add(normalization)
model4.add(Dense(40, activation='relu'))
model4.add(Dense(40, activation='relu'))
model4.add(Dense(40, activation='relu'))
model4.add(Dense(40, activation='relu'))
model4.add(Dense(40, activation='relu'))
model4.add(Dense(1, activation='linear'))
print(model4.summary())
model4.compile('adam',loss='mean_squared_error',metrics=['mean_absolute_error'])

model4.fit(train_features2,train_targets2, epochs=40, batch_size=20)

# %%
import keras
inputs = keras.Input(shape=(204,))
print(inputs.shape)
norm_inputs = normalization(inputs)
x = Dense(40, activation='relu')(norm_inputs)
x = Dense(40, activation='relu')(x)
x = Dense(40, activation='relu')(x)
x = Dense(40, activation='relu')(x)
x = Dense(40, activation='relu')(x) + Dense(40,activation='relu')(norm_inputs)
x = Dense(1, activation='linear')(x)
model5 = keras.Model(inputs=inputs, outputs=x)
print(model5.summary())
model5.compile('adam',loss='mean_squared_error',metrics=['mean_absolute_error'])

model5.fit(train_features2,train_targets2, epochs=20, batch_size=20)
